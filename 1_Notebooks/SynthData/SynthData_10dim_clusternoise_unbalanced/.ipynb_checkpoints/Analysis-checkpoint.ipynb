# %%
import os
import pandas as pd
import numpy as np

dense_summary_path = os.path.join("210503_dense", "210503_dense.csv")
LSwFW_summary_path = os.path.join("210503_LSwFW", "210503_LSwFW.csv")
LS_summary_path = os.path.join("210504_LS", "210504_LS.csv")
LSwFW_ones_summary_path = os.path.join(
    "210616_LSwFW_ones", "210616_LSwFW_ones.csv")
xgboost_summary_path = os.path.join(
    "210616_xgboost", "210616_xgboost.csv"
)
RF_summary_path = os.path.join(
    "210616_RF", "210616_RF.csv"
)
summary_df = pd.read_csv(dense_summary_path)
summary_df = pd.concat([summary_df, pd.read_csv(LSwFW_summary_path)])
summary_df = pd.concat([
    summary_df, 
    pd.read_csv(LS_summary_path), 
    pd.read_csv(LSwFW_ones_summary_path),
    pd.read_csv(xgboost_summary_path)
])

# %%
summary_df
# Out:
#       Model  n_noise_dim Metric  Split     Score
# 0     dense            1    AUC  Train  0.926257
# 1     dense            1    acc  Train  0.798889
# 2     dense            1    AUC   Test  0.874725
# 3     dense            1    acc   Test  0.680000
# 4     dense            2    AUC  Train  0.956989
# ..      ...          ...    ...    ...       ...
# 27  xgboost            7    acc   Test  0.800000
# 28  xgboost            8    AUC  Train  1.000000
# 29  xgboost            8    acc  Train  1.000000
# 30  xgboost            8    AUC   Test  0.720879
# 31  xgboost            8    acc   Test  0.690000
#
# [160 rows x 5 columns]

# %%
plot_df=summary_df.query("Metric=='AUC' & Split=='Test'")
plot_df['n_noise_dim'] = plot_df['n_noise_dim']/10.
# Out:
# <ipython-input-3-6ad9eb5d74ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['n_noise_dim'] = plot_df['n_noise_dim']/10.

# %%
summary_df.query("Metric=='AUC' & Split=='Train'")
# Out:
#          Model  n_noise_dim Metric  Split     Score
# 0        dense            1    AUC  Train  0.926257
# 4        dense            2    AUC  Train  0.956989
# 8        dense            3    AUC  Train  0.975729
# 12       dense            4    AUC  Train  0.984217
# 16       dense            5    AUC  Train  0.954274
# 20       dense            6    AUC  Train  0.987648
# 24       dense            7    AUC  Train  0.993669
# 28       dense            8    AUC  Train  0.686159
# 0        LSwFW            1    AUC  Train  0.944394
# 4        LSwFW            2    AUC  Train  0.970451
# 8        LSwFW            3    AUC  Train  0.977543
# 12       LSwFW            4    AUC  Train  0.981012
# 16       LSwFW            5    AUC  Train  0.971003
# 20       LSwFW            6    AUC  Train  0.976489
# 24       LSwFW            7    AUC  Train  0.942260
# 28       LSwFW            8    AUC  Train  0.548638
# 0           LS            1    AUC  Train  0.902065
# 4           LS            2    AUC  Train  0.945786
# 8           LS            3    AUC  Train  0.953491
# 12          LS            4    AUC  Train  0.885702
# 16          LS            5    AUC  Train  0.966801
# 20          LS            6    AUC  Train  0.980545
# 24          LS            7    AUC  Train  0.955795
# 28          LS            8    AUC  Train  0.690243
# 0   LSwFW_ones            1    AUC  Train  0.902645
# 4   LSwFW_ones            2    AUC  Train  0.957721
# 8   LSwFW_ones            3    AUC  Train  0.953728
# 12  LSwFW_ones            4    AUC  Train  0.972698
# 16  LSwFW_ones            5    AUC  Train  0.961399
# 20  LSwFW_ones            6    AUC  Train  0.981711
# 24  LSwFW_ones            7    AUC  Train  0.956172
# 28  LSwFW_ones            8    AUC  Train  0.726968
# 0      xgboost            1    AUC  Train  1.000000
# 4      xgboost            2    AUC  Train  1.000000
# 8      xgboost            3    AUC  Train  1.000000
# 12     xgboost            4    AUC  Train  1.000000
# 16     xgboost            5    AUC  Train  1.000000
# 20     xgboost            6    AUC  Train  1.000000
# 24     xgboost            7    AUC  Train  1.000000
# 28     xgboost            8    AUC  Train  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# plt.figure(figsize=(9, 5))
sns.set_theme(context="talk", style="ticks", palette="Set2")
sns.set_context("talk")
sns.set_style("ticks")
g = sns.pointplot(data=plot_df,
                  x="n_noise_dim",
                  y="Score",
                  hue="Model",
                  hue_order=["LSwFW", #"LSwFW_ones", 
                             "xgboost", "dense", "LS"],
                  linestyles=["-", ":", "-.","--","--"],
                  markers=["o", "x", "v","o","o"],
                  palette="husl",
                  #                    ax=ax,
                  )
h, l = g.get_legend_handles_labels()
leg_labels = ["Locality-Sensitive \nmodel with COSA \nfeature weights",
             # "Locality-Sensitive \nmodel with naive \nfeature weights",
              "XGBoost", 
              "Feed-forward \nneural network",
              "Locality-Sensitive \nmodel without \nfeature weights",

              ]
g.legend(handles=h,
         labels=leg_labels,
         bbox_to_anchor=(1, 1))
g.set_ylabel("AUC")
g.set_xlabel("Proportion of \ncluster-specific noise")
sns.despine()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# plt.figure(figsize=(9, 5))
sns.set_theme(context="talk", style="ticks", palette="Set2")
sns.set_context("talk")
sns.set_style("ticks")
g = sns.pointplot(data=plot_df,
                  x="n_noise_dim",
                  y="Score",
                  hue="Model",
                  hue_order=["LSwFW", "dense", "LS"],
                  linestyles=["--", "-", "-."],
                  markers=["o", "x", "v"],
                  palette="husl",
                  #                    ax=ax,
                  )
h, l = g.get_legend_handles_labels()
leg_labels = ["Locality-Sensitive \nmodel with COSA \nfeature weights",
              "Feed-forward \nneural network",
              "Locality-Sensitive \nmodel without \nfeature weights",

              ]
g.legend(handles=h,
         labels=leg_labels,
         bbox_to_anchor=(1, 1))
g.set_ylabel("AUC")
g.set_xlabel("Proportion of \ncluster-specific noise")
sns.despine()

plt.show()

# %%
leg = g.legend()

# %%
leg
